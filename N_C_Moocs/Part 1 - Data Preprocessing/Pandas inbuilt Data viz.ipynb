# %%
import numpy as np

# %%
import pandas as pd
#import seaborn as sns

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('df1')

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist',bins=30)

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()#data should be categorical

# %%
df2.plot.bar(stacked=True)#data should be categorical

# %%
df1.plot.line(x=df1.index,y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C',s=50,figsize=(18,8))# c defines the color on base of the column passed

# %%
df2.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,figsize=(18,8))
#the figsize can be passed in all funtions above

# %%
df2.plot.kde()

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].plot(kind='hist',bins=30)
